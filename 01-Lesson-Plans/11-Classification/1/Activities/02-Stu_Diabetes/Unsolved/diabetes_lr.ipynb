# %% [markdown]
# # Predicting Diabetes

# %%
from pathlib import Path
import pandas as pd

# %%
data = Path('../Resources/diabetes.csv')
df = pd.read_csv(data)
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Separate the Features (X) from the Target (y)

# %%
from sklearn.datasets import make_blobs

y = df["Outcome"]
X = df.drop(columns=["Outcome"])

print(f"Labels: {y[:10]}")
print(f"Data: {X[:10]}")
# Out:
# Labels: (array([[  1.73709966,  -0.15011294],
#        [  2.96981097,  -4.24966281],
#        [-10.33557888,   4.46566328],
#        [  4.84766946,  -2.76966945],
#        [ -9.09758723,   0.79417619],
#        [  4.10016247,   5.9996341 ],
#        [  2.84597299,   2.52037881],
#        [  3.12322989,  -8.03360631],
#        [ -5.18279107,  -4.36479257],
#        [ -8.20126216,  -1.75202784],
#        [ -2.11900021,  -3.20310487],
#        [ -9.55109929,  -6.47676625],
#        [ -4.48093018,  -6.67161506],
#        [  5.37739555,  -7.56428334],
#        [  2.85023731,   5.88469709],
#        [  3.02893337,   8.22225909],
#        [ -6.29040856,   3.49364992],
#        [-12.35609646,   0.5653319 ],
#        [  3.58748161,   1.96950154],
#        [ -1.00497975,   4.35530142],
#        [ -9.84754727,   8.15961631],
#        [ -9.42698821,  -8.16697395],
#        [  0.83577214,  -8.16894597],
#        [-10.05837983,   7.83877506],
#        [  8.66907399,   3.50722095],
#        [  7.95205312,  -7.42596489],
#        [ -2.45492097,  11.47691726],
#        [  8.36983342,   4.04079836],
#        [  0.30233749,  -6.54918419],
#        [  8.98146188,   6.45739111],
#        [  5.79296085,   3.39405926],
#        [ -6.34875831, -10.74334701],
#        [ -8.74134505,  -8.89537698],
#        [  9.6189547 ,  -0.51267697],
#        [  8.07479873,  -2.56707262],
#        [ -7.20085951,  -8.95049789],
#        [  9.82783964,   1.41293724],
#        [  4.98348076,  -0.91142811],
#        [  9.93348563,   4.77309206],
#        [ -6.7133831 ,   7.57139901],
#        [  6.81650002,  -2.96517902],
#        [  5.48041943,  -4.22238113],
#        [ -8.11035889,  11.1108617 ],
#        [ -7.47154022,   6.22496285],
#        [ -0.55014138,   2.67196661],
#        [ -2.65092375,   1.06700258],
#        [ -9.45286314,  -8.85028661],
#        [ -8.14838771,   5.61480545],
#        [  3.94739857,  -8.68698869],
#        [ -9.13575406,  -8.44209339],
#        [ -4.44081882,   4.86829431],
#        [ -4.83985819,   5.11313853],
#        [-10.72330962,  -4.82111722],
#        [ -0.14667398,  -9.40142291],
#        [  0.86372977,  10.39279639],
#        [  7.65184299,  -0.9074387 ],
#        [  7.11614388,   9.17066135],
#        [  3.53496121,   7.49790686],
#        [ -5.99212006,  -3.91488289],
#        [ -5.81548336,  -2.50441424],
#        [ -6.14889694,   8.71763661],
#        [  3.99435612,   5.31448795],
#        [ -5.74083197,  -6.65600707],
#        [  0.91361967,   5.53688429],
#        [  2.13207751,  -1.00162501],
#        [  3.97769015,   7.42264233],
#        [ -8.49297459,  -0.10296073],
#        [  1.12501094,  -9.85727246],
#        [  5.91838533,   8.35760349],
#        [  9.85012616,   8.83631116],
#        [ -6.93086184,   2.49762302],
#        [ -7.1551501 ,  -1.52693486],
#        [  6.22858666,  -3.77522267],
#        [ -5.90797624,   7.99410484],
#        [  8.02911427,  -4.94885262],
#        [-10.2524596 ,  -3.42694402],
#        [ -8.14822676,   0.75328822],
#        [  2.23297904,  -6.44259244],
#        [ -5.29785332,  -8.59109178],
#        [ -6.23795709,   1.73228839],
#        [ -6.5130925 ,   6.15221227],
#        [ -1.44356781,   1.73245638],
#        [  5.87256245,   9.99986655],
#        [ -3.47301868,  -4.92495611],
#        [ -4.1760659 ,   4.75774591],
#        [ -9.36686695,   0.40147293],
#        [  9.50988065,   1.54692448],
#        [  7.94193719,   4.08056369],
#        [ -0.10373053,   8.19072467],
#        [ -4.24496079,   1.65700315],
#        [ -2.32195022,   4.89707608],
#        [  0.23442333,   8.68545261],
#        [ -1.07094439,  10.52970014],
#        [  2.33563333,  -7.47845781],
#        [ -7.03234693,  -6.90711785],
#        [  3.62082836,   4.55955006],
#        [ -9.01408179,   4.53167853],
#        [ -7.84781687,  -4.02978727],
#        [ -8.62502588,  -3.28602396],
#        [  2.63499354,  -3.31561659]]), array([33, 88, 19, 17, 25, 96, 44, 90, 26, 15, 47, 98, 24, 59, 81, 99, 78,
#        49, 84,  0, 45, 71, 66, 53, 56, 35, 85, 69, 70, 79, 40, 82, 13, 16,
#        38,  2, 48, 41, 20, 14, 68, 67, 75, 57, 46,  8, 72, 36, 91, 60, 73,
#        21,  1, 27, 65, 62, 12, 18,  3, 30,  6, 39,  9, 87, 31, 10, 22, 74,
#        58, 97, 93, 80, 23, 42, 51, 89, 32, 76, 95, 11, 92,  4, 54, 37, 77,
#        83, 34, 52, 63, 50,  5, 94, 43, 28, 55, 29,  7, 64, 61, 86]))
# Data: (array([[  1.73709966,  -0.15011294],
#        [  2.96981097,  -4.24966281],
#        [-10.33557888,   4.46566328],
#        [  4.84766946,  -2.76966945],
#        [ -9.09758723,   0.79417619],
#        [  4.10016247,   5.9996341 ],
#        [  2.84597299,   2.52037881],
#        [  3.12322989,  -8.03360631],
#        [ -5.18279107,  -4.36479257],
#        [ -8.20126216,  -1.75202784],
#        [ -2.11900021,  -3.20310487],
#        [ -9.55109929,  -6.47676625],
#        [ -4.48093018,  -6.67161506],
#        [  5.37739555,  -7.56428334],
#        [  2.85023731,   5.88469709],
#        [  3.02893337,   8.22225909],
#        [ -6.29040856,   3.49364992],
#        [-12.35609646,   0.5653319 ],
#        [  3.58748161,   1.96950154],
#        [ -1.00497975,   4.35530142],
#        [ -9.84754727,   8.15961631],
#        [ -9.42698821,  -8.16697395],
#        [  0.83577214,  -8.16894597],
#        [-10.05837983,   7.83877506],
#        [  8.66907399,   3.50722095],
#        [  7.95205312,  -7.42596489],
#        [ -2.45492097,  11.47691726],
#        [  8.36983342,   4.04079836],
#        [  0.30233749,  -6.54918419],
#        [  8.98146188,   6.45739111],
#        [  5.79296085,   3.39405926],
#        [ -6.34875831, -10.74334701],
#        [ -8.74134505,  -8.89537698],
#        [  9.6189547 ,  -0.51267697],
#        [  8.07479873,  -2.56707262],
#        [ -7.20085951,  -8.95049789],
#        [  9.82783964,   1.41293724],
#        [  4.98348076,  -0.91142811],
#        [  9.93348563,   4.77309206],
#        [ -6.7133831 ,   7.57139901],
#        [  6.81650002,  -2.96517902],
#        [  5.48041943,  -4.22238113],
#        [ -8.11035889,  11.1108617 ],
#        [ -7.47154022,   6.22496285],
#        [ -0.55014138,   2.67196661],
#        [ -2.65092375,   1.06700258],
#        [ -9.45286314,  -8.85028661],
#        [ -8.14838771,   5.61480545],
#        [  3.94739857,  -8.68698869],
#        [ -9.13575406,  -8.44209339],
#        [ -4.44081882,   4.86829431],
#        [ -4.83985819,   5.11313853],
#        [-10.72330962,  -4.82111722],
#        [ -0.14667398,  -9.40142291],
#        [  0.86372977,  10.39279639],
#        [  7.65184299,  -0.9074387 ],
#        [  7.11614388,   9.17066135],
#        [  3.53496121,   7.49790686],
#        [ -5.99212006,  -3.91488289],
#        [ -5.81548336,  -2.50441424],
#        [ -6.14889694,   8.71763661],
#        [  3.99435612,   5.31448795],
#        [ -5.74083197,  -6.65600707],
#        [  0.91361967,   5.53688429],
#        [  2.13207751,  -1.00162501],
#        [  3.97769015,   7.42264233],
#        [ -8.49297459,  -0.10296073],
#        [  1.12501094,  -9.85727246],
#        [  5.91838533,   8.35760349],
#        [  9.85012616,   8.83631116],
#        [ -6.93086184,   2.49762302],
#        [ -7.1551501 ,  -1.52693486],
#        [  6.22858666,  -3.77522267],
#        [ -5.90797624,   7.99410484],
#        [  8.02911427,  -4.94885262],
#        [-10.2524596 ,  -3.42694402],
#        [ -8.14822676,   0.75328822],
#        [  2.23297904,  -6.44259244],
#        [ -5.29785332,  -8.59109178],
#        [ -6.23795709,   1.73228839],
#        [ -6.5130925 ,   6.15221227],
#        [ -1.44356781,   1.73245638],
#        [  5.87256245,   9.99986655],
#        [ -3.47301868,  -4.92495611],
#        [ -4.1760659 ,   4.75774591],
#        [ -9.36686695,   0.40147293],
#        [  9.50988065,   1.54692448],
#        [  7.94193719,   4.08056369],
#        [ -0.10373053,   8.19072467],
#        [ -4.24496079,   1.65700315],
#        [ -2.32195022,   4.89707608],
#        [  0.23442333,   8.68545261],
#        [ -1.07094439,  10.52970014],
#        [  2.33563333,  -7.47845781],
#        [ -7.03234693,  -6.90711785],
#        [  3.62082836,   4.55955006],
#        [ -9.01408179,   4.53167853],
#        [ -7.84781687,  -4.02978727],
#        [ -8.62502588,  -3.28602396],
#        [  2.63499354,  -3.31561659]]), array([33, 88, 19, 17, 25, 96, 44, 90, 26, 15, 47, 98, 24, 59, 81, 99, 78,
#        49, 84,  0, 45, 71, 66, 53, 56, 35, 85, 69, 70, 79, 40, 82, 13, 16,
#        38,  2, 48, 41, 20, 14, 68, 67, 75, 57, 46,  8, 72, 36, 91, 60, 73,
#        21,  1, 27, 65, 62, 12, 18,  3, 30,  6, 39,  9, 87, 31, 10, 22, 74,
#        58, 97, 93, 80, 23, 42, 51, 89, 32, 76, 95, 11, 92,  4, 54, 37, 77,
#        83, 34, 52, 63, 50,  5, 94, 43, 28, 55, 29,  7, 64, 61, 86]))

# %% [markdown]
# ## Split our data into training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
# Out:
# c:\Users\karen\anaconda3\envs\dev\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17312/2400513626.py in <module>
#       4                                                     y,
#       5                                                     random_state=1,
# ----> 6                                                     stratify=y)
#
# c:\Users\karen\anaconda3\envs\dev\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2195                      random_state=random_state)
#    2196
# -> 2197         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2198
#    2199     return list(chain.from_iterable((_safe_indexing(a, train),
#
# c:\Users\karen\anaconda3\envs\dev\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1791         to an integer.
#    1792         """
# -> 1793         y = check_array(y, ensure_2d=False, dtype=None)
#    1794         return super().split(X, y, groups)
#    1795
#
# c:\Users\karen\anaconda3\envs\dev\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\Users\karen\anaconda3\envs\dev\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# c:\Users\karen\anaconda3\envs\dev\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not broadcast input array from shape (100,2) into shape (100,)

# %% [markdown]
# ## Create a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs', random_state=1)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=1, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ## Fit (train) or model using the training data

# %%
# YOUR CODE HERE!

# %% [markdown]
# ## Score the model using the test data

# %%
# YOUR CODE HERE!
# Out:
# Training Data Score: 0.7743055555555556
# Testing Data Score: 0.7552083333333334

# %% [markdown]
# ## Make predictions

# %%
# YOUR CODE HERE!
# Out:
#      Prediction  Actual
# 0             0       0
# 1             1       1
# 2             0       0
# 3             1       1
# 4             0       0
# 5             0       0
# 6             1       1
# 7             1       0
# 8             1       1
# 9             0       0
# 10            1       1
# 11            0       1
# 12            0       0
# 13            1       1
# 14            0       1
# 15            0       1
# 16            0       0
# 17            0       0
# 18            1       1
# 19            0       0
# 20            0       0
# 21            0       1
# 22            0       0
# 23            0       0
# 24            0       0
# 25            1       1
# 26            1       1
# 27            0       0
# 28            0       0
# 29            0       0
# ..          ...     ...
# 162           0       0
# 163           0       0
# 164           0       0
# 165           1       0
# 166           1       0
# 167           0       0
# 168           0       1
# 169           1       1
# 170           0       0
# 171           0       0
# 172           0       0
# 173           0       0
# 174           0       0
# 175           0       1
# 176           0       1
# 177           0       0
# 178           0       0
# 179           0       0
# 180           0       1
# 181           0       0
# 182           0       0
# 183           0       0
# 184           0       0
# 185           1       1
# 186           0       0
# 187           1       1
# 188           0       0
# 189           0       0
# 190           0       0
# 191           0       0
#
# [192 rows x 2 columns]
